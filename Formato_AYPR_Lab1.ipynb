# %% [markdown]
# <a href="https://colab.research.google.com/github/patricia2/aypr/blob/main/Formato_AYPR_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problema**
#
# Mario debe ascender una pirámide de bloques.
#
# ![mario1.png](data:image/png;base64,...)

# %% [markdown]
# Escriba un programa que, dada la altura, ***height***, pinte una pirámide de bloques como la de la siguiente figura:
#
# ![piramide1.png](data:image/png;base64,...)

# %% [markdown]
# Pregunte al usuario la altura tantas veces como sea necesario si la entrada no es un entero o no es mayor que 0 o es mayor que 8.

# %% [markdown]
# **Paso a paso sugerido**

# %% [markdown]
# 1. Escriba a continuación las primeras líneas de código:
#
#     Documentación
#
#     Definición de función principal
#
#     Imprimir saludo

# %%
# xxxx

def xxxxx():
    print()

# %% [markdown]
# 2. Escriba en seudo código el proceso

# %%
# xxxx

def xxxxx():
    print()

    # Preguntar altura de la piramide

    # Validar que sea un entero

    # Validar que sea un valor mayor que 0 y menor o igual que 8


    # Imprimir pirámide

# %% [markdown]
# 3. Convierta el seudo código a código Python.
#
# Recuerde que usted ya cuenta con una función que lee y valida que el valor ingresado sea un entero.
#
# También cuenta con otra función que valida que el valor sea mayor que 5. Puede modificarla y usarla en esta solución.

# %%
# xxxx

def xxxxx():
    print()

    # Preguntar altura de la piramide

    # Validar que sea un entero

    # Validar que sea un valor mayor que 0 y menor o igual que 8


    # Imprimir pirámide

# %% [markdown]
# 4. Recuerde, se debe repetir la lectura de la altura si no cumple con las condiciones y restricciones dadas. Considere usar una estrucutura repetitiva o ciclo.
#
# Piense cuáles son las instrucciones que se repiten, porque estas son las instrucciones que conforman el cuerpo del ciclo.
#
# También, piense en cuál sería una condición de terminación para el ciclo. Es posible usar una variable booleana adicional, por ejemplo:
#
# valido = False

# %%
# xxxx

def xxxxx():
    print()
    while ???:
      # Preguntar altura de la piramide y validar que sea un entero

      # Validar que sea un valor mayor que 0 y menor o igual que 8
    #end_while


    # Imprimir pirámide

# %% [markdown]
# 5. Ahora piense en cómo imprimir la pirámide de arriba a abajo según la altura dada. Observe que la primera línea o fila sólo tiene un bloque alineado a la derecha, la segunda tiene dos bloques alineados a la derecha, la tercera tiene tres bloques alineados a la derecha, y así sucesivamente se sigue repitiendo hasta lograr la altura requerida. En cada iteración se incrementa un bloque.
#
# Esto parece un ciclo, con un contador que se va incrementando....

# %%
# xxxx

def xxxxx():
    print()
    while ???:
      # Preguntar altura de la piramide y validar que sea un entero

      # Validar que sea un valor mayor que 0 y menor o igual que 8
    #end_while


    # Imprimir pirámide

    # inicializar el contador

    while ???:

      # imprimir linea o fila

      # instrucción que producirá la terminación del ciclo

# %% [markdown]
# 6. Recuerde que usted ya cuenta con una función que hace alineación a la derecha, la puede reutilizar.

# %%
# xxxx
def alinea_derecha(xx):




def xxxxx():
    print()
    while ???:
      # Preguntar altura de la piramide y validar que sea un entero

      # Validar que sea un valor mayor que 0 y menor o igual que 8
    #end_while


    # Imprimir pirámide

    # inicializar el contador

    while ???:

      # imprimir linea o fila

      llamado a funcion alinea_derecha

      # instrucción que producirá la terminación del ciclo

    #end_while

xxx()

# %% [markdown]
# 7. Finalmente elimine todos los comentarios del seudo código y haga las pruebas al programa.
#
# Pruebe con 0
# Pruebe ingresando letras
# Pruebe con 9
# Pruebe con valores negativos, -1
# Pruebe digitando Enter simplemente
# Pruebe con un entero váldo para este problema

# %%
# xxxx
def alinea_derecha(xx):



def xxxxx():
    print()
    while ???:

    #end_while

    while ???:

      llamado a funcion alinea_derecha

    #end_while

xxx()
